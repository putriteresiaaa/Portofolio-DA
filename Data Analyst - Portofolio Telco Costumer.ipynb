# %% [markdown]
# # Telco Customer Churn Prediction

# %% [markdown]
# ## - Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## - Load Dataset

# %%
# Read in the data

df = pd.read_csv(r'/Users/putriteresiaompusunggu/Downloads/Telco_Customer.csv',sep=';')

# Look at the data

df.head()
# Out:
#    customerid   region  gender  seniorcitizen partner dependents  tenure  \
# 0  2424-WVHPL   France    Male              1      No         No       1
# 1  3679-XASPY   France  Female              0     Yes        Yes       1
# 2  2967-MXRAV  Germany    Male              0     Yes        Yes       1
# 3  8992-CEUEN  Germany  Female              0      No         No       1
# 4  9318-NKNFC  Germany    Male              0      No         No       1
#
#   phoneservice multiplelines internetservice  ...         onlinebackup  \
# 0          Yes            No     Fiber optic  ...                   No
# 1          Yes            No              No  ...  No internet service
# 2          Yes            No              No  ...  No internet service
# 3          Yes            No              No  ...  No internet service
# 4          Yes            No              No  ...  No internet service
#
#       deviceprotection          techsupport          streamingtv  \
# 0                   No                  Yes                   No
# 1  No internet service  No internet service  No internet service
# 2  No internet service  No internet service  No internet service
# 3  No internet service  No internet service  No internet service
# 4  No internet service  No internet service  No internet service
#
#        streamingmovies paperlessbilling     paymentmethod monthlycharges  \
# 0                   No               No  Electronic check          12.00
# 1  No internet service               No  Electronic check          13.00
# 2  No internet service               No      Mailed check          18.80
# 3  No internet service               No  Electronic check          18.85
# 4  No internet service              Yes      Mailed check          18.85
#
#    totalcharges churn
# 0            12    No
# 1            13    No
# 2          18.8    No
# 3         18.85    No
# 4         18.85   Yes
#
# [5 rows x 21 columns]

# %%
# View the number of rows and columns in the data

df.shape
# Out:
# (7043, 21)

# %%
# Understanding each variable

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   region            7043 non-null   object
#  2   gender            7043 non-null   object
#  3   seniorcitizen     7043 non-null   int64
#  4   partner           7043 non-null   object
#  5   dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   phoneservice      7043 non-null   object
#  8   multiplelines     7043 non-null   object
#  9   internetservice   7043 non-null   object
#  10  onlinesecurity    7043 non-null   object
#  11  onlinebackup      7043 non-null   object
#  12  deviceprotection  7043 non-null   object
#  13  techsupport       7043 non-null   object
#  14  streamingtv       7043 non-null   object
#  15  streamingmovies   7043 non-null   object
#  16  paperlessbilling  7043 non-null   object
#  17  paymentmethod     7043 non-null   object
#  18  monthlycharges    7043 non-null   float64
#  19  totalcharges      7043 non-null   object
#  20  churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
# See a statistical summary of variables with numeric types

df.describe()
# Out:
#        seniorcitizen       tenure  monthlycharges  totalcharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.401107       64.751874   2283.470948
# std         0.368612    24.606849       30.097858   2267.649278
# min         0.000000     1.000000       12.000000     12.000000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3793.050000
# max         1.000000   120.000000      118.750000   8879.287500

# %% [markdown]
# ## - Data Cleaning and Preprocessing

# %%
# Check duplicate data

df.drop_duplicates()
# Out:
#       customerid   region  gender  seniorcitizen partner dependents  tenure  \
# 0     2424-WVHPL   France    Male              1      No         No       1
# 1     3679-XASPY   France  Female              0     Yes        Yes       1
# 2     2967-MXRAV  Germany    Male              0     Yes        Yes       1
# 3     8992-CEUEN  Germany  Female              0      No         No       1
# 4     9318-NKNFC  Germany    Male              0      No         No       1
# ...          ...      ...     ...            ...     ...        ...     ...
# 7038  4472-LVYGI  Germany  Female              0     Yes        Yes       2
# 7039  1371-DWPAZ  Germany  Female              0     Yes        Yes       2
# 7040  2775-SEFEE  Germany    Male              0      No        Yes       3
# 7041  4075-WKNIU  Germany  Female              0     Yes        Yes       3
# 7042  5709-LVOEQ  Germany  Female              0     Yes        Yes       3
#
#      phoneservice     multiplelines internetservice  ...         onlinebackup  \
# 0             Yes                No     Fiber optic  ...                   No
# 1             Yes                No              No  ...  No internet service
# 2             Yes                No              No  ...  No internet service
# 3             Yes                No              No  ...  No internet service
# 4             Yes                No              No  ...  No internet service
# ...           ...               ...             ...  ...                  ...
# 7038           No  No phone service             DSL  ...                   No
# 7039           No  No phone service             DSL  ...                  Yes
# 7040          Yes               Yes             DSL  ...                  Yes
# 7041          Yes               Yes             DSL  ...                  Yes
# 7042          Yes                No             DSL  ...                  Yes
#
#          deviceprotection          techsupport          streamingtv  \
# 0                      No                  Yes                   No
# 1     No internet service  No internet service  No internet service
# 2     No internet service  No internet service  No internet service
# 3     No internet service  No internet service  No internet service
# 4     No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7038                  Yes                  Yes                  Yes
# 7039                  Yes                  Yes                  Yes
# 7040                   No                  Yes                   No
# 7041                  Yes                  Yes                  Yes
# 7042                  Yes                   No                  Yes
#
#           streamingmovies paperlessbilling              paymentmethod  \
# 0                      No               No           Electronic check
# 1     No internet service               No           Electronic check
# 2     No internet service               No               Mailed check
# 3     No internet service               No           Electronic check
# 4     No internet service              Yes               Mailed check
# ...                   ...              ...                        ...
# 7038                   No              Yes  Bank transfer (automatic)
# 7039                   No               No    Credit card (automatic)
# 7040                   No              Yes  Bank transfer (automatic)
# 7041                   No               No               Mailed check
# 7042                  Yes               No               Mailed check
#
#      monthlycharges  totalcharges churn
# 0             12.00            12    No
# 1             13.00            13    No
# 2             18.80          18.8    No
# 3             18.85         18.85    No
# 4             18.85         18.85   Yes
# ...             ...           ...   ...
# 7038          52.55                  No
# 7039          56.05                  No
# 7040          61.90                  No
# 7041          73.35                  No
# 7042          80.85                  No
#
# [7043 rows x 21 columns]

# %%
# See changes in the number of rows and columns after the duplicate value is deleted

df.shape
# Out:
# (7043, 21)

# %%
# Check data types

df.dtypes
# Out:
# customerid           object
# region               object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges         object
# churn                object
# dtype: object

# %%
# Change the value "null" to "space"

df ['totalcharges'] = df['totalcharges'].replace(' ', np.nan)

# %%
# Change data type

df ['totalcharges'] = df ['totalcharges'].astype('float64')

# %%
df.dtypes
# Out:
# customerid           object
# region               object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges        float64
# churn                object
# dtype: object

# %% [markdown]
# ## - Check Missing Value

# %%
# Check the missing value

df.isnull().sum()
# Out:
# customerid          0
# region              0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %% [markdown]
# ## - Impute Missing Value

# %%
# Look at the distribution of the "totalcharges" variable with histogram and density plot

plt.figure(figsize = (10,5))
sns.distplot(df['totalcharges'])
plt.show()
# Out:
# /Users/putriteresiaompusunggu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Look at the distribution of the totalcharges variable with boxplot

plt.figure(figsize=(10,5))
sns.boxplot(df["totalcharges"])
plt.show()
# Out:
# /Users/putriteresiaompusunggu/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Because the totalcharges variable has positive skewed, therefore the missing value is imputed with the median

fill=df["totalcharges"].median()
df["totalcharges"] = df["totalcharges"].fillna(fill)

# %%
# Check missing value after imputation

df.isnull().sum()
# Out:
# customerid          0
# region              0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %% [markdown]
# ## - Outlier Detection

# %%
# Check Outlier on the Tenure variable

plt.figure(figsize=(10,5))
sns.boxplot(df["tenure"])
plt.show()
# Out:
# /Users/putriteresiaompusunggu/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Check Outlier on the monthlycharges variable

plt.figure(figsize=(10,5))
sns.boxplot(df["monthlycharges"])
plt.show()
# Out:
# /Users/putriteresiaompusunggu/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Check Outlier on the totalcharges variable
plt.figure(figsize=(10,5))
sns.boxplot(df["totalcharges"])
plt.show()
# Out:
# /Users/putriteresiaompusunggu/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# See observation outliers on the totalcharges variable

Q1 = df["totalcharges"].quantile(0.25)
Q3 = df["totalcharges"].quantile(0.75)
IQR = Q3-Q1
lower_range = Q1 -(1.5 * IQR)
upper_range = Q3 +(1.5 * IQR)
df.loc[(df["totalcharges"] > upper_range),:]
# Out:
#       customerid   region  gender  seniorcitizen partner dependents  tenure  \
# 7024  2889-FPWRM  Germany    Male              0     Yes         No      96
# 7025  7892-POOKP   France  Female              0     Yes         No     120
# 7026  7569-NMZYQ  Germany  Female              0     Yes        Yes      72
# 7027  9739-JLPQJ  Germany  Female              0     Yes        Yes      72
# 7028  9924-JPRMC  Germany    Male              0      No         No      72
# 7029  8879-XUAHX  Germany    Male              0     Yes         No      71
# 7030  9788-HNGUT  Germany    Male              0     Yes         No      72
# 7031  6007-TCTST  Germany  Female              0     Yes        Yes      72
#
#      phoneservice multiplelines internetservice  ... onlinebackup  \
# 7024          Yes           Yes     Fiber optic  ...          Yes
# 7025          Yes           Yes     Fiber optic  ...           No
# 7026          Yes           Yes     Fiber optic  ...          Yes
# 7027          Yes           Yes     Fiber optic  ...          Yes
# 7028          Yes           Yes     Fiber optic  ...          Yes
# 7029          Yes           Yes     Fiber optic  ...          Yes
# 7030          Yes           Yes     Fiber optic  ...          Yes
# 7031          Yes           Yes     Fiber optic  ...          Yes
#
#      deviceprotection techsupport streamingtv streamingmovies  \
# 7024              Yes         Yes         Yes             Yes
# 7025              Yes         Yes         Yes             Yes
# 7026              Yes         Yes         Yes             Yes
# 7027              Yes         Yes         Yes             Yes
# 7028              Yes         Yes         Yes             Yes
# 7029              Yes         Yes         Yes             Yes
# 7030              Yes         Yes         Yes             Yes
# 7031              Yes         Yes         Yes             Yes
#
#      paperlessbilling              paymentmethod monthlycharges  totalcharges  \
# 7024              Yes  Bank transfer (automatic)         117.80       11308.8
# 7025              Yes           Electronic check         104.80       12576.0
# 7026              Yes  Bank transfer (automatic)         118.75       15087.9
# 7027               No    Credit card (automatic)         117.50       16987.9
# 7028              Yes           Electronic check         118.20       17987.3
# 7029              Yes           Electronic check         116.25       18987.9
# 7030              Yes    Credit card (automatic)         116.95       21987.5
# 7031              Yes  Bank transfer (automatic)         115.80       22345.6
#
#       churn
# 7024    Yes
# 7025    Yes
# 7026     No
# 7027     No
# 7028     No
# 7029     No
# 7030     No
# 7031     No
#
# [8 rows x 21 columns]

# %%
# Replace outlier observations with upper bound and lower bound

df.loc[(df["totalcharges"] > upper_range),"totalcharges"]=upper_range

# %%
# Check Outlier on the totalcharges variable

plt.figure(figsize=(10,5))
sns.boxplot(df["totalcharges"])
plt.show()
# Out:
# /Users/putriteresiaompusunggu/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
